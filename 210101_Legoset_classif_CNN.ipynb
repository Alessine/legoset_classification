# %% [markdown]
# # Legoset classification with Keras and Tensorflow
#
# This notebook is based on an in-class exercise at [Propulsion Academy](https://propulsion.academy/).
#
# The fine-tuning of the network was further inspired by these articles:
# - https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b
# - https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
import seaborn as sns
sns.set_palette("muted")

from datetime import datetime
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

# !pip install -U tensorboard_plugin_profile
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, Nadam

import os
import PIL

from google.colab import drive
# Out:
# Requirement already up-to-date: tensorboard_plugin_profile in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.0.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (3.12.4)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (51.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.15.0)
# Requirement already satisfied, skipping upgrade: gviz-api>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.9.0)

# %%
#drive.flush_and_unmount()
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# locate data in the gdrive
project_dir = "/gdrive/MyDrive/Colab Notebooks/Legosets_classif"

images_dir = project_dir + '/images'
# %cd {project_dir} 
# %pwd
# Out:
# /gdrive/MyDrive/Colab Notebooks/Legosets_classif
# '/gdrive/MyDrive/Colab Notebooks/Legosets_classif'

# %% [markdown]
# ## Import the data frame with the image names
#
# The data and images used here were scraped from ads on [Ricardo](https://www.ricardo.ch/). The corresponding code is available in one of my other repos: https://github.com/Alessine/ricardo_webscraping.

# %%
legosets_raw = pd.read_csv("lego_sets.csv", index_col = 0)

# %%
legosets_df = legosets_raw.copy()

# %%
# Basic cleaning of the data set
legosets_df = legosets_df.drop_duplicates(subset = "image_url")
legosets_df = legosets_df.dropna(axis = 0, subset = ["title"])

# %%
legosets_df.head()
# Out:
#        line                                title  ...   time_remaining sale_type
# 0  starwars              Lego Star Wars Sammlung  ...  1 days 19:11:05   buy_now
# 1  starwars             Lego Star Wars 75080 AAT  ...  6 days 23:26:02   buy_now
# 2  starwars  Lego SW Minifigur Biggs Darklighter  ...  0 days 05:15:58   auction
# 3  starwars     Lego SW Minifigur Obi Wan Kenobi  ...  0 days 05:13:54   auction
# 4  starwars                Star Wars Battle Pack  ...  0 days 01:40:50   auction
#
# [5 rows x 10 columns]

# %%
len(legosets_df), legosets_df.value_counts("line")
# Out:
# (1051, line
#  duplo       356
#  starwars    354
#  technic     341
#  dtype: int64)

# %% [markdown]
# ## Split the data into train, validation and test sets

# %%
train_all, test = train_test_split(legosets_df, test_size=0.1)
train, val = train_test_split(train_all, test_size=0.1)
train.shape, val.shape, test.shape
# Out:
# ((850, 10), (95, 10), (106, 10))

# %%
fig, axs = plt.subplots(1, 3, figsize = (15, 6), sharey = True)

sns.countplot(data = train.sort_values("line"), x = "line", ax = axs[0])
sns.countplot(data = val.sort_values("line"), x = "line", ax = axs[1])
sns.countplot(data = test.sort_values("line"), x = "line", ax = axs[2])

axs[0].set_title("Training Set")
axs[1].set_title("Validation Set")
axs[2].set_title("Test Set");

# %%
x_col = 'image_name' # column in the df with local paths to images
y_col = "line" # column in the df with the names of the classes

print("'{}' column contains {} unique classes".format(y_col, train[y_col].unique().shape[0]))
# Out:
# 'line' column contains 3 unique classes

# %% [markdown]
# ## Image preprocessing and augmentation
#
# Image augmentation can help prevent overfitting and improve the results. However, it should not distort the images so much that the classification is no longer possible. The simple options that I have chosen already showed a big improvement in the accuracy of the classifications.
#
# Additionally, the images also need to be scaled to the right input size and the pixels to values between 0 and 1.

# %%
IMG_SIZE = 224
batch_size = 50

#need to pass the class names to the .flow_from_dataframe method
train_classes = train[y_col].unique()
train_classes = np.sort(train_classes).tolist()

datagen_train = tf.keras.preprocessing.image.ImageDataGenerator(
                      rescale=1./255,
                      width_shift_range=0.2,
                      height_shift_range=0.2,
                      #zoom_range=[0.9, 1.1],
                      brightness_range=(0.9,1.1)
                      )

train_generator = datagen_train.flow_from_dataframe(
    dataframe = train,
    directory = images_dir,
    shuffle = True,
    x_col = x_col,
    y_col = y_col,
    classes = train_classes,
    class_mode = 'sparse',       # Sparse because all the labels are saved in the same column.
    target_size = (IMG_SIZE, IMG_SIZE), 
    batch_size = batch_size)
# Out:
# Found 850 validated image filenames belonging to 3 classes.

# %%
train_classes
# Out:
# ['duplo', 'starwars', 'technic']

# %%
# Plot 5 images:
sample_training_images, _ = next(train_generator)
fig, axs = plt.subplots(1, 5, figsize = (15, 5))
for i in range(0, 5):
  axs[i].imshow(sample_training_images[i])
  axs[i].set_xticks([])
  axs[i].set_yticks([]);

# %% [markdown]
# The validation and test sets only need to be rescaled.

# %%
datagen_val=tf.keras.preprocessing.image.ImageDataGenerator(
                      rescale=1./255
                      )

val_generator=datagen_val.flow_from_dataframe(
    dataframe=val,
    directory=images_dir, 
    x_col=x_col,
    y_col=y_col,
    class_mode='sparse',
    classes=train_classes,
    shuffle=False,
    target_size=(IMG_SIZE, IMG_SIZE), 
    batch_size=batch_size)

test_generator = datagen_val.flow_from_dataframe(
    dataframe=test,
    directory=images_dir, 
    x_col=x_col,
    y_col=y_col,
    class_mode='sparse',
    classes=train_classes,
    shuffle=False,
    target_size=(IMG_SIZE, IMG_SIZE), 
    batch_size=batch_size)
# Out:
# Found 95 validated image filenames belonging to 3 classes.
# Found 106 validated image filenames belonging to 3 classes.

# %% [markdown]
# ## Defining other model inputs

# %%
# The number of steps depends on the number of images and the batch size. It needs to be rounded to integers.
steps_train = round(train_generator.n / batch_size)
steps_val = round(val_generator.n / batch_size)
steps_test = round(test_generator.n / batch_size)

# %%
train_generator.n, steps_train
# Out:
# (850, 17)

# %%
# This creates lists of all the class labels in the training and the test set.

cls_train = train_generator.classes
cls_test = test_generator.classes
len(cls_train)
# Out:
# 850

# %%
# Calculate the class weights based on the labels in the training set.

class_weight = compute_class_weight(class_weight='balanced',
                                    classes=np.unique(cls_train),
                                    y=cls_train)
class_weight
# Out:
# array([0.99067599, 1.02657005, 0.9837963 ])

# %%
# Turn into dictionary
class_weight_dict = {i : class_weight[i] for i in range(0, len(class_weight))}
class_weight_dict
# Out:
# {0: 0.9906759906759907, 1: 1.0265700483091786, 2: 0.9837962962962963}

# %% [markdown]
# ## Building the model

# %%
# Load the ResNet50 model without the top layers.
model_name = 'resnet50_v01'
model = tf.keras.applications.resnet50.ResNet50(input_shape = (224,224,3),
                                              include_top = False,
                                              weights = 'imagenet',
                                                    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
# This is what the structure looks like.
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# In order to apply the ResNet50 model to this specific data set, I added a couple of new layers as the top. The final output now consists of three probabilities, corresponding to the classes of the lego sets.

# %%
# Create a new model with resnet

last_conv_layer = model.get_layer('conv5_block3_out')
conv_model = Model(inputs=model.input,
                   outputs=last_conv_layer.output)

new_model = Sequential()

new_model.add(conv_model)

new_model.add(tf.keras.layers.Dense(256, activation='relu'))
new_model.add(tf.keras.layers.Dropout(0.5))
new_model.add(tf.keras.layers.BatchNormalization())
new_model.add(tf.keras.layers.Dense(128, activation='relu'))
new_model.add(tf.keras.layers.Dropout(0.5))
new_model.add(tf.keras.layers.GlobalAveragePooling2D())
new_model.add(tf.keras.layers.Dense(3, activation='softmax'))   # Softmax activation function returns probabilities.

# %%
# Make the model trainable and define from what layers onwards
conv_model.trainable = True

fine_tune_at = 143  # This means only the last block will be trainable.

# Freeze all the layers before the `fine_tune_at` layer
for layer in conv_model.layers[:fine_tune_at]:
  layer.trainable =  False

# %% [markdown]
# ## Compiling the model
#
# The learning rate should be low, so the weights from the ResNet50 model change only slowly during training.

# %%
base_learning_rate = 2e-5
optimizer = Nadam(lr=base_learning_rate/5)
loss = 'sparse_categorical_crossentropy'
lst_metrics = ['sparse_categorical_accuracy']

new_model.compile(optimizer=optimizer, loss=loss, metrics=lst_metrics)
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# dense (Dense)                (None, 7, 7, 256)         524544
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 7, 7, 256)         1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 7, 7, 128)         32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 24,146,563
# Trainable params: 15,534,339
# Non-trainable params: 8,612,224
# _________________________________________________________________

# %% [markdown]
# ## Defining callbacks

# %%
# Use Tensorboard
logs = "logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")

tboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logs,
                                                 histogram_freq = 1,
                                                 profile_batch = '500,520')

# Can use this at a later point.

# %%
# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss', min_delta = 0.005, patience = 10, verbose = 1,
    mode = 'auto', baseline = None, restore_best_weights = True
)

# %%
# Learning rate scheduler
def scheduler(epoch, lr):
  if epoch < 20:
    return lr
  else:
    return lr * tf.math.exp(-0.1)

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler)

# I tried this, but with the Adam or Nadam optimizer it does not yield better results.

# %% [markdown]
# ## Training the model

# %%
# A high number of epochs is fine, since training stops once the loss stops to decrease.
epochs = 120
history = new_model.fit(train_generator,
                    epochs = epochs,
                    steps_per_epoch = steps_train,
                    class_weight = class_weight_dict,
                    validation_data = val_generator,
                    callbacks = [
                                 tboard_callback, 
                                 early_stopping,
                          #       lr_schedule
                                 ])
# Out:
# Epoch 1/120
# 17/17 [==============================] - 278s 16s/step - loss: 1.1660 - sparse_categorical_accuracy: 0.3535 - val_loss: 1.3534 - val_sparse_categorical_accuracy: 0.4000
# Epoch 2/120
# 17/17 [==============================] - 39s 2s/step - loss: 1.1211 - sparse_categorical_accuracy: 0.3903 - val_loss: 1.2919 - val_sparse_categorical_accuracy: 0.4000
# Epoch 3/120
# 17/17 [==============================] - 39s 2s/step - loss: 1.0618 - sparse_categorical_accuracy: 0.4386 - val_loss: 1.2505 - val_sparse_categorical_accuracy: 0.3579
# Epoch 4/120
# 17/17 [==============================] - 39s 2s/step - loss: 1.0321 - sparse_categorical_accuracy: 0.4518 - val_loss: 1.2199 - val_sparse_categorical_accuracy: 0.2737
# Epoch 5/120
# 17/17 [==============================] - 39s 2s/step - loss: 1.0345 - sparse_categorical_accuracy: 0.4534 - val_loss: 1.1991 - val_sparse_categorical_accuracy: 0.2526
# Epoch 6/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.9982 - sparse_categorical_accuracy: 0.4606 - val_loss: 1.1824 - val_sparse_categorical_accuracy: 0.2526
# Epoch 7/120
# 17/17 [==============================] - 39s 2s/step - loss: 1.0042 - sparse_categorical_accuracy: 0.4828 - val_loss: 1.1737 - val_sparse_categorical_accuracy: 0.2526
# Epoch 8/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.9756 - sparse_categorical_accuracy: 0.4989 - val_loss: 1.1716 - val_sparse_categorical_accuracy: 0.2526
# Epoch 9/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.9753 - sparse_categorical_accuracy: 0.4970 - val_loss: 1.1747 - val_sparse_categorical_accuracy: 0.2526
# Epoch 10/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.9614 - sparse_categorical_accuracy: 0.5232 - val_loss: 1.1764 - val_sparse_categorical_accuracy: 0.2526
# Epoch 11/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.9396 - sparse_categorical_accuracy: 0.5692 - val_loss: 1.1715 - val_sparse_categorical_accuracy: 0.2526
# Epoch 12/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.9270 - sparse_categorical_accuracy: 0.5878 - val_loss: 1.1653 - val_sparse_categorical_accuracy: 0.2526
# Epoch 13/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.9196 - sparse_categorical_accuracy: 0.5936 - val_loss: 1.1559 - val_sparse_categorical_accuracy: 0.2526
# Epoch 14/120
# 17/17 [==============================] - 40s 2s/step - loss: 0.9026 - sparse_categorical_accuracy: 0.5788 - val_loss: 1.1388 - val_sparse_categorical_accuracy: 0.2526
# Epoch 15/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8858 - sparse_categorical_accuracy: 0.6045 - val_loss: 1.1216 - val_sparse_categorical_accuracy: 0.2526
# Epoch 16/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8881 - sparse_categorical_accuracy: 0.6193 - val_loss: 1.1041 - val_sparse_categorical_accuracy: 0.3684
# Epoch 17/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8748 - sparse_categorical_accuracy: 0.6187 - val_loss: 1.0852 - val_sparse_categorical_accuracy: 0.3895
# Epoch 18/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8657 - sparse_categorical_accuracy: 0.6188 - val_loss: 1.0627 - val_sparse_categorical_accuracy: 0.4000
# Epoch 19/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8466 - sparse_categorical_accuracy: 0.6607 - val_loss: 1.0390 - val_sparse_categorical_accuracy: 0.4316
# Epoch 20/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8269 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.0176 - val_sparse_categorical_accuracy: 0.4526
# Epoch 21/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8359 - sparse_categorical_accuracy: 0.6537 - val_loss: 0.9983 - val_sparse_categorical_accuracy: 0.4947
# Epoch 22/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.8157 - sparse_categorical_accuracy: 0.6675 - val_loss: 0.9774 - val_sparse_categorical_accuracy: 0.5158
# Epoch 23/120
# 17/17 [==============================] - 40s 2s/step - loss: 0.7952 - sparse_categorical_accuracy: 0.6872 - val_loss: 0.9580 - val_sparse_categorical_accuracy: 0.5263
# Epoch 24/120
# 17/17 [==============================] - 40s 2s/step - loss: 0.7870 - sparse_categorical_accuracy: 0.6706 - val_loss: 0.9341 - val_sparse_categorical_accuracy: 0.5368
# Epoch 25/120
# 17/17 [==============================] - 40s 2s/step - loss: 0.8040 - sparse_categorical_accuracy: 0.6676 - val_loss: 0.9163 - val_sparse_categorical_accuracy: 0.5579
# Epoch 26/120
# 17/17 [==============================] - 40s 2s/step - loss: 0.7855 - sparse_categorical_accuracy: 0.6755 - val_loss: 0.9031 - val_sparse_categorical_accuracy: 0.5579
# Epoch 27/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7697 - sparse_categorical_accuracy: 0.6720 - val_loss: 0.8754 - val_sparse_categorical_accuracy: 0.5789
# Epoch 28/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7774 - sparse_categorical_accuracy: 0.6765 - val_loss: 0.8664 - val_sparse_categorical_accuracy: 0.5895
# Epoch 29/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7618 - sparse_categorical_accuracy: 0.6810 - val_loss: 0.8467 - val_sparse_categorical_accuracy: 0.6421
# Epoch 30/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7599 - sparse_categorical_accuracy: 0.6853 - val_loss: 0.8378 - val_sparse_categorical_accuracy: 0.6526
# Epoch 31/120
# 17/17 [==============================] - 42s 2s/step - loss: 0.7414 - sparse_categorical_accuracy: 0.6988 - val_loss: 0.8305 - val_sparse_categorical_accuracy: 0.6632
# Epoch 32/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7249 - sparse_categorical_accuracy: 0.7096 - val_loss: 0.8283 - val_sparse_categorical_accuracy: 0.6632
# Epoch 33/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7210 - sparse_categorical_accuracy: 0.7182 - val_loss: 0.8103 - val_sparse_categorical_accuracy: 0.6632
# Epoch 34/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7083 - sparse_categorical_accuracy: 0.7255 - val_loss: 0.8083 - val_sparse_categorical_accuracy: 0.6421
# Epoch 35/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6943 - sparse_categorical_accuracy: 0.7364 - val_loss: 0.7969 - val_sparse_categorical_accuracy: 0.6316
# Epoch 36/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.7168 - sparse_categorical_accuracy: 0.7050 - val_loss: 0.7866 - val_sparse_categorical_accuracy: 0.6632
# Epoch 37/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6886 - sparse_categorical_accuracy: 0.7189 - val_loss: 0.7806 - val_sparse_categorical_accuracy: 0.7053
# Epoch 38/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6852 - sparse_categorical_accuracy: 0.7320 - val_loss: 0.7670 - val_sparse_categorical_accuracy: 0.6842
# Epoch 39/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6854 - sparse_categorical_accuracy: 0.7302 - val_loss: 0.7817 - val_sparse_categorical_accuracy: 0.6526
# Epoch 40/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6645 - sparse_categorical_accuracy: 0.7443 - val_loss: 0.7901 - val_sparse_categorical_accuracy: 0.6632
# Epoch 41/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6703 - sparse_categorical_accuracy: 0.7334 - val_loss: 0.7761 - val_sparse_categorical_accuracy: 0.6211
# Epoch 42/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6573 - sparse_categorical_accuracy: 0.7536 - val_loss: 0.7632 - val_sparse_categorical_accuracy: 0.6211
# Epoch 43/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6504 - sparse_categorical_accuracy: 0.7578 - val_loss: 0.7510 - val_sparse_categorical_accuracy: 0.6526
# Epoch 44/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6399 - sparse_categorical_accuracy: 0.7197 - val_loss: 0.7404 - val_sparse_categorical_accuracy: 0.6632
# Epoch 45/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6737 - sparse_categorical_accuracy: 0.7377 - val_loss: 0.7275 - val_sparse_categorical_accuracy: 0.6737
# Epoch 46/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6464 - sparse_categorical_accuracy: 0.7597 - val_loss: 0.7278 - val_sparse_categorical_accuracy: 0.6632
# Epoch 47/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6119 - sparse_categorical_accuracy: 0.7709 - val_loss: 0.7209 - val_sparse_categorical_accuracy: 0.6526
# Epoch 48/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6183 - sparse_categorical_accuracy: 0.7679 - val_loss: 0.7153 - val_sparse_categorical_accuracy: 0.6526
# Epoch 49/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6213 - sparse_categorical_accuracy: 0.7489 - val_loss: 0.7098 - val_sparse_categorical_accuracy: 0.6842
# Epoch 50/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6127 - sparse_categorical_accuracy: 0.7693 - val_loss: 0.6975 - val_sparse_categorical_accuracy: 0.6842
# Epoch 51/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6652 - sparse_categorical_accuracy: 0.7059 - val_loss: 0.6904 - val_sparse_categorical_accuracy: 0.7158
# Epoch 52/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.6214 - sparse_categorical_accuracy: 0.7526 - val_loss: 0.6833 - val_sparse_categorical_accuracy: 0.6947
# Epoch 53/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5695 - sparse_categorical_accuracy: 0.7812 - val_loss: 0.6801 - val_sparse_categorical_accuracy: 0.6842
# Epoch 54/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.6103 - sparse_categorical_accuracy: 0.7538 - val_loss: 0.6731 - val_sparse_categorical_accuracy: 0.6737
# Epoch 55/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.6188 - sparse_categorical_accuracy: 0.7523 - val_loss: 0.6736 - val_sparse_categorical_accuracy: 0.6947
# Epoch 56/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.5570 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.6771 - val_sparse_categorical_accuracy: 0.7053
# Epoch 57/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5721 - sparse_categorical_accuracy: 0.7775 - val_loss: 0.6814 - val_sparse_categorical_accuracy: 0.6737
# Epoch 58/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5544 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.6412 - val_sparse_categorical_accuracy: 0.6947
# Epoch 59/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5683 - sparse_categorical_accuracy: 0.7928 - val_loss: 0.6440 - val_sparse_categorical_accuracy: 0.6947
# Epoch 60/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.5325 - sparse_categorical_accuracy: 0.8076 - val_loss: 0.6265 - val_sparse_categorical_accuracy: 0.7263
# Epoch 61/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.5138 - sparse_categorical_accuracy: 0.8183 - val_loss: 0.6363 - val_sparse_categorical_accuracy: 0.6737
# Epoch 62/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.5626 - sparse_categorical_accuracy: 0.7899 - val_loss: 0.6648 - val_sparse_categorical_accuracy: 0.6947
# Epoch 63/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5068 - sparse_categorical_accuracy: 0.8190 - val_loss: 0.6368 - val_sparse_categorical_accuracy: 0.7053
# Epoch 64/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.5263 - sparse_categorical_accuracy: 0.8008 - val_loss: 0.6288 - val_sparse_categorical_accuracy: 0.7053
# Epoch 65/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5133 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.6328 - val_sparse_categorical_accuracy: 0.7053
# Epoch 66/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5119 - sparse_categorical_accuracy: 0.8117 - val_loss: 0.6484 - val_sparse_categorical_accuracy: 0.6842
# Epoch 67/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5199 - sparse_categorical_accuracy: 0.8206 - val_loss: 0.6268 - val_sparse_categorical_accuracy: 0.7053
# Epoch 68/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4879 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.6263 - val_sparse_categorical_accuracy: 0.7053
# Epoch 69/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4925 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.6300 - val_sparse_categorical_accuracy: 0.7263
# Epoch 70/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4762 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.5941 - val_sparse_categorical_accuracy: 0.7263
# Epoch 71/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5239 - sparse_categorical_accuracy: 0.8006 - val_loss: 0.5828 - val_sparse_categorical_accuracy: 0.7474
# Epoch 72/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.5331 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.5820 - val_sparse_categorical_accuracy: 0.7474
# Epoch 73/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4948 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.5850 - val_sparse_categorical_accuracy: 0.7368
# Epoch 74/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4798 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.5886 - val_sparse_categorical_accuracy: 0.7368
# Epoch 75/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5206 - sparse_categorical_accuracy: 0.7978 - val_loss: 0.5698 - val_sparse_categorical_accuracy: 0.7579
# Epoch 76/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.5194 - sparse_categorical_accuracy: 0.8005 - val_loss: 0.5724 - val_sparse_categorical_accuracy: 0.7474
# Epoch 77/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4764 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.5827 - val_sparse_categorical_accuracy: 0.7263
# Epoch 78/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4840 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.5626 - val_sparse_categorical_accuracy: 0.7579
# Epoch 79/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4666 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.5739 - val_sparse_categorical_accuracy: 0.7579
# Epoch 80/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4548 - sparse_categorical_accuracy: 0.8395 - val_loss: 0.5766 - val_sparse_categorical_accuracy: 0.7368
# Epoch 81/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4792 - sparse_categorical_accuracy: 0.8258 - val_loss: 0.5870 - val_sparse_categorical_accuracy: 0.7474
# Epoch 82/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4425 - sparse_categorical_accuracy: 0.8394 - val_loss: 0.5557 - val_sparse_categorical_accuracy: 0.7474
# Epoch 83/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4345 - sparse_categorical_accuracy: 0.8446 - val_loss: 0.5727 - val_sparse_categorical_accuracy: 0.7263
# Epoch 84/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4819 - sparse_categorical_accuracy: 0.8482 - val_loss: 0.5751 - val_sparse_categorical_accuracy: 0.7368
# Epoch 85/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4428 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.5355 - val_sparse_categorical_accuracy: 0.7474
# Epoch 86/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.4671 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.5658 - val_sparse_categorical_accuracy: 0.7579
# Epoch 87/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.4660 - sparse_categorical_accuracy: 0.8258 - val_loss: 0.5486 - val_sparse_categorical_accuracy: 0.7579
# Epoch 88/120
# 17/17 [==============================] - 39s 2s/step - loss: 0.4413 - sparse_categorical_accuracy: 0.8526 - val_loss: 0.5509 - val_sparse_categorical_accuracy: 0.7684
# Epoch 89/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4471 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.5500 - val_sparse_categorical_accuracy: 0.7579
# Epoch 90/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4769 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.5746 - val_sparse_categorical_accuracy: 0.7684
# Epoch 91/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4069 - sparse_categorical_accuracy: 0.8587 - val_loss: 0.5635 - val_sparse_categorical_accuracy: 0.7684
# Epoch 92/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4217 - sparse_categorical_accuracy: 0.8545 - val_loss: 0.5638 - val_sparse_categorical_accuracy: 0.7579
# Epoch 93/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4162 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.5681 - val_sparse_categorical_accuracy: 0.7789
# Epoch 94/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.4461 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.5548 - val_sparse_categorical_accuracy: 0.7684
# Epoch 95/120
# 17/17 [==============================] - 38s 2s/step - loss: 0.3976 - sparse_categorical_accuracy: 0.8630 - val_loss: 0.5383 - val_sparse_categorical_accuracy: 0.7684
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping

# %%
pd.DataFrame(history.history).plot(figsize = (12, 8));

# %%
new_model.save(f"{project_dir}/{datetime.now().strftime('%Y%m%d-%H%M%S')}_resnet50_model")
# Out:
# INFO:tensorflow:Assets written to: /gdrive/MyDrive/Colab Notebooks/Legosets_classif/20210101-193443_resnet50_model/assets

# %%
#new_model = tf.keras.models.load_model(f"{project_dir}/20201230-205011_resnet50_model")

# %% [markdown]
# ## Testing the model

# %%
test_history = new_model.predict(
                        test_generator,
                        steps=steps_test,
                        callbacks=None,
                        max_queue_size=10,
                        workers=-1,
                        use_multiprocessing=False,
                        verbose=1)
# Out:
# 2/2 [==============================] - 17s 15s/step

# %% [markdown]
# ## Evaluating the model

# %%
# Results data frame
df_test_results = pd.DataFrame()
df_test_results['y_true'] = test_generator.labels[:100]
df_test_results['y_pred'] = test_history.argmax(axis = -1)
df_test_results.head()
# Out:
#    y_true  y_pred
# 0       0       0
# 1       1       1
# 2       1       1
# 3       1       0
# 4       2       2

# %%
# Print the classification report
print(classification_report(df_test_results['y_true'], 
                            df_test_results['y_pred'],
                            target_names = train_classes))
# Out:
#               precision    recall  f1-score   support
#
#        duplo       0.81      0.76      0.78        33
#     starwars       0.81      0.74      0.77        39
#      technic       0.67      0.79      0.72        28
#
#     accuracy                           0.76       100
#    macro avg       0.76      0.76      0.76       100
# weighted avg       0.77      0.76      0.76       100

# %%
# Confusion matrix
labels = np.sort(df_test_results['y_true'].unique())
conf_mat = metrics.confusion_matrix(df_test_results['y_true'], 
                                    df_test_results['y_pred'],
                                    labels = labels)

df_conf = pd.DataFrame(conf_mat, columns = train_classes, index = train_classes)

fig, ax = plt.subplots(figsize=(14,10))
sns.set(font_scale=1.2)
sns.heatmap(df_conf, annot = True, ax = ax, cmap = "GnBu")
ax.set_xlabel("Predicted Class")
ax.set_ylabel("True Class")
plt.show()

# %% [markdown]
# ## Showing some of the predictions

# %%
input_shape = (224, 224)
row = test.iloc[2,:]

image_path = os.path.join(images_dir, row['image_name'])

img = PIL.Image.open(image_path)
img_resized = img.resize(input_shape, PIL.Image.LANCZOS)

# Plot the image.
plt.imshow(img_resized)
plt.xticks([])
plt.yticks([])
plt.show()

# Print the prediction and the true class.
print(f"Probabilities: {test_history[2].round(3)}")
print(f"Predicted class: {train_classes[df_test_results['y_pred'][2]]}")
print('\ntrue class:', train_classes[df_test_results['y_true'][2]])
# Out:
# Probabilities: [0.003 0.82  0.177]
# Predicted class: starwars
#
# true class: starwars

# %%
input_shape = (224, 224)
row = test.iloc[30,:]

image_path = os.path.join(images_dir, row['image_name'])

img = PIL.Image.open(image_path)
img_resized = img.resize(input_shape, PIL.Image.LANCZOS)

# Plot the image.
plt.imshow(img_resized)
plt.xticks([])
plt.yticks([])
plt.show()

# Print the prediction and the true class.
print(f"Probabilities: {test_history[30].round(3)}")
print(f"Predicted class: {train_classes[df_test_results['y_pred'][30]]}")
print('\ntrue class:', train_classes[df_test_results['y_true'][30]])
# Out:
# Probabilities: [0.009 0.604 0.387]
# Predicted class: starwars
#
# true class: starwars

# %%
input_shape = (224, 224)
row = test.iloc[81,:]

image_path = os.path.join(images_dir, row['image_name'])

img = PIL.Image.open(image_path)
img_resized = img.resize(input_shape, PIL.Image.LANCZOS)

# Plot the image.
plt.imshow(img_resized)
plt.xticks([])
plt.yticks([])
plt.show()

# Print the prediction and the true class.
print(f"Probabilities: {test_history[81].round(3)}")
print(f"Predicted class: {train_classes[df_test_results['y_pred'][81]]}")
print('\ntrue class:', train_classes[df_test_results['y_true'][81]])
# Out:
# Probabilities: [0.111 0.281 0.608]
# Predicted class: technic
#
# true class: duplo
